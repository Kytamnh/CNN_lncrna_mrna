# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install Bio
# Out:
# Collecting Bio
#   Downloading bio-1.6.0-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.4/279.4 kB 4.9 MB/s eta 0:00:00
# Collecting biopython>=1.80 (from Bio)
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 58.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from Bio) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from Bio) (4.66.1)
# Collecting mygene (from Bio)
#   Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from Bio) (1.5.3)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from Bio) (1.8.0)
# Collecting gprofiler-official (from Bio)
#   Downloading gprofiler_official-1.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython>=1.80->Bio) (1.23.5)
# Collecting biothings-client>=0.2.6 (from mygene->Bio)
#   Downloading biothings_client-0.3.1-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Bio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Bio) (2023.3.post1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch->Bio) (4.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch->Bio) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->Bio) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->Bio) (1.16.0)
# Installing collected packages: biopython, gprofiler-official, biothings-client, mygene, Bio
# Successfully installed Bio-1.6.0 biopython-1.81 biothings-client-0.3.1 gprofiler-official-1.0.0 mygene-3.2.2

# %%
from Bio import SeqIO
import numpy as np
import pandas as pd
def extract_kmers(sequence, k):
    kmers = []
    for i in range(len(sequence) - k + 1):
        kmer = sequence[i:i + k]
        kmers.append(kmer)
    return kmers

# Read mRNA sequences
mRNA_file = '/content/drive/MyDrive/lncRna-vs-mRna-main/lncRna-vs-mRna-main/mRNA.fasta'
mRNA_data = list(SeqIO.parse(mRNA_file, 'fasta'))

# Read lncRNA sequences
lncRNA_file = '/content/drive/MyDrive/lncRna-vs-mRna-main/lncRna-vs-mRna-main/lncRNA.fasta'
lncRNA_data = list(SeqIO.parse(lncRNA_file, 'fasta'))

# %%
from Bio import SeqIO
import numpy as np
import pandas as pd


# Read mRNA sequences
mRNA_file = '/content/drive/MyDrive/lncRna-vs-mRna-main/lncRna-vs-mRna-main/mRNA.fasta'
mRNA_data = list(SeqIO.parse(mRNA_file, 'fasta'))

# Read lncRNA sequences
lncRNA_file = '/content/drive/MyDrive/lncRna-vs-mRna-main/lncRna-vs-mRna-main/lncRNA.fasta'
lncRNA_data = list(SeqIO.parse(lncRNA_file, 'fasta'))


combined_sequences = [str(record.seq).upper() for record in mRNA_data] + [str(record.seq).upper() for record in lncRNA_data]

def extract_kmers(sequence, k):
    kmers = []
    for i in range(len(sequence) - k + 1):
        kmer = sequence[i:i + k]
        kmers.append(kmer)
    return kmers

all_kmers_set_1 = set()
k = 1  # Set the value of k for k-mer extraction
all_kmers_set_2 = set()
k = 2  # Set the value of k for k-mer extraction
all_kmers_set_3 = set()
k = 3  # Set the value of k for k-mer extraction
all_kmers_set_4 = set()
k = 4  # Set the value of k for k-mer extraction

for sequence in combined_sequences:
    kmers_1 = extract_kmers(sequence, 1)
    all_kmers_set_1.update(kmers_1)
    kmers_2 = extract_kmers(sequence, 2)
    all_kmers_set_2.update(kmers_2)
    kmers_3 = extract_kmers(sequence, 3)
    all_kmers_set_3.update(kmers_3)
    kmers_4 = extract_kmers(sequence, 4)
    all_kmers_set_4.update(kmers_4)

# %%
def create_kmer_matrix(fasta_data, all_kmers_set, k):
    num_sequences = len(fasta_data)
    num_unique_kmers = len(all_kmers_set)
    kmer_matrix = np.zeros((num_sequences, num_unique_kmers), dtype=int)

    for i, record in enumerate(fasta_data):
        sequence = str(record.seq).upper()

        # Extract k-mers using a sliding window
        kmers = extract_kmers(sequence, k)

        # Fill in the matrix with k-mer frequencies
        for j, kmer in enumerate(all_kmers_set):
            kmer_matrix[i, j] = kmers.count(kmer)

    return kmer_matrix

# %%
mRNA_kmer_matrix_1 = create_kmer_matrix(mRNA_data, all_kmers_set_1, 1)
lncRNA_kmer_matrix_1 = create_kmer_matrix(lncRNA_data, all_kmers_set_1, 1)


mRNA_kmer_matrix_2 = create_kmer_matrix(mRNA_data, all_kmers_set_2, 2)
lncRNA_kmer_matrix_2 = create_kmer_matrix(lncRNA_data, all_kmers_set_2, 2)


mRNA_kmer_matrix_3 = create_kmer_matrix(mRNA_data, all_kmers_set_3, 3)
lncRNA_kmer_matrix_3 = create_kmer_matrix(lncRNA_data, all_kmers_set_3, 3)


mRNA_kmer_matrix_4 = create_kmer_matrix(mRNA_data, all_kmers_set_4, 4)
lncRNA_kmer_matrix_4 = create_kmer_matrix(lncRNA_data, all_kmers_set_4, 4)

# %%
def preprocess(mRNA_kmer_matrix,lncRNA_kmer_matrix):
  max=mRNA_kmer_matrix.max() if mRNA_kmer_matrix.max()>lncRNA_kmer_matrix.max() else lncRNA_kmer_matrix.max()
  mRNA_kmer_matrix=mRNA_kmer_matrix/max
  lncRNA_kmer_matrix=lncRNA_kmer_matrix/max
  ones_column = np.ones((mRNA_kmer_matrix.shape[0], 1))
  zeros_column=np.zeros((lncRNA_kmer_matrix.shape[0],1))
  mRNA_kmer_matrix = np.hstack((mRNA_kmer_matrix, ones_column))
  lncRNA_kmer_matrix = np.hstack((lncRNA_kmer_matrix, zeros_column))
  df_mrna = pd.DataFrame(mRNA_kmer_matrix)
  df_lncRNA=pd.DataFrame(lncRNA_kmer_matrix)
  return df_mrna,df_lncRNA

# %%
df_mrna_1,df_lncRNA_1 = preprocess(mRNA_kmer_matrix_1,lncRNA_kmer_matrix_1)
df_mrna_2,df_lncRNA_2 = preprocess(mRNA_kmer_matrix_2,lncRNA_kmer_matrix_2)
df_mrna_3,df_lncRNA_3 = preprocess(mRNA_kmer_matrix_3,lncRNA_kmer_matrix_3)
df_mrna_4,df_lncRNA_4 = preprocess(mRNA_kmer_matrix_4,lncRNA_kmer_matrix_4)

# %%
df_mrna_4
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.006667  0.026667  0.040000  0.013333  0.026667  0.013333  0.000000
# 1     0.020000  0.000000  0.013333  0.000000  0.026667  0.006667  0.000000
# 2     0.006667  0.006667  0.006667  0.013333  0.000000  0.006667  0.000000
# 3     0.006667  0.006667  0.006667  0.020000  0.020000  0.013333  0.006667
# 4     0.000000  0.006667  0.040000  0.006667  0.000000  0.006667  0.006667
# ...        ...       ...       ...       ...       ...       ...       ...
# 4551  0.006667  0.000000  0.000000  0.006667  0.000000  0.006667  0.006667
# 4552  0.006667  0.020000  0.026667  0.013333  0.026667  0.026667  0.006667
# 4553  0.000000  0.013333  0.033333  0.013333  0.020000  0.000000  0.013333
# 4554  0.000000  0.006667  0.013333  0.000000  0.006667  0.000000  0.006667
# 4555  0.013333  0.013333  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            7         8         9    ...       247       248       249  \
# 0     0.040000  0.033333  0.006667  ...  0.020000  0.013333  0.006667
# 1     0.026667  0.040000  0.020000  ...  0.026667  0.040000  0.020000
# 2     0.013333  0.013333  0.013333  ...  0.000000  0.033333  0.000000
# 3     0.026667  0.006667  0.053333  ...  0.006667  0.020000  0.006667
# 4     0.033333  0.006667  0.026667  ...  0.000000  0.000000  0.006667
# ...        ...       ...       ...  ...       ...       ...       ...
# 4551  0.033333  0.000000  0.000000  ...  0.000000  0.000000  0.020000
# 4552  0.133333  0.026667  0.053333  ...  0.040000  0.066667  0.013333
# 4553  0.033333  0.006667  0.046667  ...  0.013333  0.006667  0.006667
# 4554  0.060000  0.013333  0.006667  ...  0.000000  0.000000  0.006667
# 4555  0.020000  0.000000  0.026667  ...  0.006667  0.020000  0.000000
#
#            250       251       252       253       254       255  256
# 0     0.026667  0.073333  0.006667  0.026667  0.020000  0.020000  1.0
# 1     0.000000  0.026667  0.053333  0.046667  0.000000  0.006667  1.0
# 2     0.013333  0.026667  0.026667  0.013333  0.000000  0.000000  1.0
# 3     0.000000  0.066667  0.020000  0.020000  0.006667  0.013333  1.0
# 4     0.000000  0.046667  0.060000  0.006667  0.000000  0.020000  1.0
# ...        ...       ...       ...       ...       ...       ...  ...
# 4551  0.000000  0.006667  0.013333  0.013333  0.000000  0.000000  1.0
# 4552  0.100000  0.053333  0.120000  0.086667  0.020000  0.033333  1.0
# 4553  0.013333  0.046667  0.040000  0.026667  0.000000  0.046667  1.0
# 4554  0.013333  0.053333  0.000000  0.026667  0.000000  0.020000  1.0
# 4555  0.006667  0.046667  0.006667  0.020000  0.013333  0.013333  1.0
#
# [4556 rows x 257 columns]

# %%
from google.colab import files
df_mrna_1.to_csv('df_mrna1.csv', index=False)
df_lncRNA_1.to_csv('df_lnRNA1.csv',index=False)
df_mrna_2.to_csv('df_mrna2.csv', index=False)
df_lncRNA_2.to_csv('df_lnRNA2.csv',index=False)
df_mrna_3.to_csv('df_mrna3.csv', index=False)
df_lncRNA_3.to_csv('df_lnRNA3.csv',index=False)
df_mrna_4.to_csv('df_mrna4.csv', index=False)
df_lncRNA_4.to_csv('df_lnRNA4.csv',index=False)
files.download('df_mrna1.csv')
files.download('df_lnRNA1.csv')
files.download('df_mrna2.csv')
files.download('df_lnRNA2.csv')
files.download('df_mrna3.csv')
files.download('df_lnRNA3.csv')
files.download('df_mrna4.csv')
files.download('df_lnRNA4.csv')
